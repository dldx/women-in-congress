# %%
import json
import pandas as pd

import numpy as np
import glob

# %%
members = pd.read_hdf("list_of_members.h5", "members")
members["full_name_"] = members["first_name"] + " " + members["last_name"]
members["last_name_lower"] = members["last_name"].str.lower()

# %%
state_names = {
    "AL": "Alabama",
    "AK": "Alaska",
    "AS": "American Samoa",
    "AZ": "Arizona",
    "AR": "Arkansas",
    "CA": "California",
    "CO": "Colorado",
    "CT": "Connecticut",
    "DE": "Delaware",
    "DC": "District Of Columbia",
    "FM": "Federated States Of Micronesia",
    "FL": "Florida",
    "GA": "Georgia",
    "GU": "Guam",
    "HI": "Hawaii",
    "ID": "Idaho",
    "IL": "Illinois",
    "IN": "Indiana",
    "IA": "Iowa",
    "KS": "Kansas",
    "KY": "Kentucky",
    "LA": "Louisiana",
    "ME": "Maine",
    "MH": "Marshall Islands",
    "MD": "Maryland",
    "MA": "Massachusetts",
    "MI": "Michigan",
    "MN": "Minnesota",
    "MS": "Mississippi",
    "MO": "Missouri",
    "MT": "Montana",
    "NE": "Nebraska",
    "NV": "Nevada",
    "NH": "New Hampshire",
    "NJ": "New Jersey",
    "NM": "New Mexico",
    "NY": "New York",
    "NC": "North Carolina",
    "ND": "North Dakota",
    "MP": "Northern Mariana Islands",
    "OH": "Ohio",
    "OK": "Oklahoma",
    "OR": "Oregon",
    "PW": "Palau",
    "PA": "Pennsylvania",
    "PR": "Puerto Rico",
    "RI": "Rhode Island",
    "SC": "South Carolina",
    "SD": "South Dakota",
    "TN": "Tennessee",
    "TX": "Texas",
    "UT": "Utah",
    "VT": "Vermont",
    "VI": "Virgin Islands",
    "VA": "Virginia",
    "WA": "Washington",
    "WV": "West Virginia",
    "WI": "Wisconsin",
    "WY": "Wyoming"
}

state_names = {v: k for k, v in state_names.items()}

# %%
def speech_to_df(speech_filename, chamber='house'):
    """
    This function reads in a json and converts it to a pandas dataframe.
    It also tries to find missing bioguide ids if they exist in the data.
    """
    from pandas.io.json import json_normalize
    from fuzzywuzzy import fuzz
    from fuzzywuzzy import process

    # Load json from file
    speech_json = json.load(open(speech_filename))
    # flatten json into dataframes
    speeches = json_normalize(speech_json["content"])
    metadata = json_normalize(speech_json).drop(["content"], axis=1)
    
    # Add filename to dataframe
    #speeches["file"] = speech_filename
    
   # Join dataframes together, duplicating info over all rows
    df = speeches.join(pd.DataFrame(np.repeat(metadata.values, len(speeches), axis=0), columns=metadata.columns))
    # Create a date column
    df["date"] = pd.to_datetime(df["header.day"] + " " + df["header.month"] + " " + df["header.year"])
    # Make lower case
    df["header.chamber"] = df["header.chamber"].str.lower()
    
    # Keep only one chamber and only only speech rows
    speech_df = df.loc[(df["kind"] == 'speech') & (df["header.chamber"] == chamber.lower())].copy()
    
    ## If there are any speeches without a bioguide id, let's try to find the appropriate person
    if ("speaker_bioguide" in speech_df.columns) and (len(speech_df.query("speaker_bioguide == 'None'")) > 0):
        # Assume that there is only one unknown speaker per dataframe
        unknown_speaker = speech_df.loc[speech_df["speaker_bioguide"] == "None"].iloc[0]
        # Get the title row which may contain a full name
        title_rows = df.query("kind=='title'")

        if len(title_rows) > 0:
            #print(speech_filename, " Num. rows: ", len(title_rows))
            title_row = title_rows.iloc[0]["text"].split("\n")[0].strip()

            # Get list of possible members based on last name
            if " of " in unknown_speaker["speaker"]:
                # Then we also have a location
                list_of_possible_members = members.loc[(members["term_start"] < unknown_speaker["date"]) &
                            (members["term_end"] > unknown_speaker["date"]) &
                            (members["state"] == state_names[unknown_speaker["speaker"].split(" of ")[1]]) &
                            (members["type"] == ("rep" if unknown_speaker["header.chamber"] == "House" else "sen")) &
                            (members["last_name_lower"] == (unknown_speaker["speaker"].split(" of ")[0].split(" ")[-1].lower()))]\
                            .set_index("full_name_")["bioguide_id"]
            else:
                list_of_possible_members = members.loc[(members["term_start"] < unknown_speaker["date"]) &
                            (members["term_end"] > unknown_speaker["date"]) &
                            (members["type"] == ("rep" if unknown_speaker["header.chamber"] == "House" else "sen")) &
                            (members["last_name_lower"] == (unknown_speaker["speaker"].split(" ")[-1].lower()))]\
                            .set_index("full_name_")["bioguide_id"]

            if len(list_of_possible_members) == 1:
                # Reverse match using name to get bioguide id and set that as the id for all missing rows
                speech_df.loc[speech_df["speaker_bioguide"] == "None", "speaker_bioguide"] = list_of_possible_members.iloc[0]
                speech_df["changed"] = True
            elif len(list_of_possible_members) > 1:
                best_match = process.extractOne(title_row, list_of_possible_members.index.tolist(), scorer=fuzz.token_set_ratio)
                if best_match[1] > 85:
                    # Good match so let's use it
                    # Reverse match using name to get bioguide id and set that as the id for all missing rows
                    speech_df.loc[speech_df["speaker_bioguide"] == "None", "speaker_bioguide"] = list_of_possible_members.to_dict()[best_match[0]]
                    speech_df["changed"] = True

    if len(speech_df) > 0:
        # Group speeches together if by the same person
        speech_df = speech_df.groupby(["speaker", "speaker_bioguide", "id", "doc_title", "date"])\
            .apply(lambda x: " ".join(x.text)).reset_index().rename(columns={0:"body"})

        return speech_df

# %%
# %%time
from multiprocessing import Pool

files = glob.glob("/media/Stuff/congressional-record/output/**/json/*", recursive=True)

with Pool(8) as pool:
    speeches = pd.concat(list(pool.map(speech_to_df, files)), ignore_index=True).drop("index", axis=1)
# Out:
# CPU times: user 6min 18s, sys: 20.5 s, total: 6min 38s
# Wall time: 45min 39s

# %%
speeches.join(members[["bioguide_id", "first_name", "last_name", "gender"]]\
                                    .drop_duplicates().set_index("bioguide_id"), on="speaker_bioguide")
# Out:
#                                                      body       date  \
# 0         Mr. LANGEVIN. Mr. Speaker, I rise in support... 2001-03-30
# 1         Mr. BOEHLERT. Mr. Speaker, I rise in strong ... 2001-03-30
# 2         Mr. LARSON of Connecticut. Mr. Speaker, I ri... 2001-03-30
# 3         Mr. SCOTT. Mr. Speaker, in celebration of Wo... 2001-03-30
# 4         Mr. LANGEVIN. Mr. Chairman, I rise today in ... 2001-03-30
# 5         Mr. MORAN of Kansas. Mr. Speaker, March Madn... 2001-03-30
# 6         Mr. CHAMBLISS. Mr. Speaker, I want to recogn... 2001-03-30
# 7         Mr. DeFAZIO. Mr. Speaker, this weekend is no... 2001-03-30
# 8         Mr. HASTINGS of Florida. Mr. Speaker, I rise... 2001-03-30
# 9         Mr. RILEY. Mr. Speaker, I would like to welc... 2001-03-30
# 10        Mr. DeFAZIO. Mr. Speaker, I move that the Ho... 2001-03-30
# 11        Mr. MATHESON. Mr. Speaker, I rise today to h... 2001-11-30
# 12        Mr. GORDON. Mr. Speaker, I rise today to bid... 2001-11-30
# 13        Mr. ISRAEL. Mr. Speaker, New York's economy ... 2001-11-30
# 14        Mr. RADANOVICH. Mr. Speaker, I rise today to... 2001-11-30
# 15        Mr. BORSKI. Mr. Speaker, let me first commen... 2001-11-30
# 16        Mr. KOLBE. Mr. Speaker, I rise in support of... 2001-11-30
# 17        Mr. McDERMOTT. Mr. Speaker, on rollcall No. ... 2001-11-30
# 18        Mr. OBERSTAR. Mr. Speaker, I thank the gentl... 2001-11-30
# 19        Mr. OLVER. Mr. Speaker, I thank the gentlema... 2001-11-30
# 20        Mr. PASTOR. Mr. Speaker, I thank the gentlem... 2001-11-30
# 21        Mr. ROGERS of Kentucky. Pursuant to House Re... 2001-11-30
# 22        Mr. SABO. Mr. Speaker, I yield myself such t... 2001-11-30
# 23        Mr. WOLF. Mr. Speaker, I want to congratulat... 2001-11-30
# 24        Mr. YOUNG of Florida. Mr. Speaker, I thank t... 2001-11-30
# 25        Ms. KILPATRICK. Mr. Speaker, I, too, was a m... 2001-11-30
# 26        Mrs. MORELLA. Mr. Speaker, I rise to explain... 2001-11-30
# 27        Mr. ROGERS of Kentucky. Mr. Speaker, I ask u... 2001-11-30
# 28        Mr. FARR of California. Mr. Speaker, today I... 2001-11-30
# 29        Mr. PENCE. Mr. Speaker, on September 11 our ... 2001-11-30
# ...                                                   ...        ...
# 460386    Mr. PAXON. Mr. Speaker, will the gentleman y... 1997-07-31
# 460387    Mr. QUINN. Mr. Speaker, after a momentous mo... 1997-07-31
# 460388    Ms. ROS-LEHTINEN. Mr. Speaker, will the gent... 1997-07-31
# 460389    Mr. DREIER. Mr. Speaker, what an incredible ... 1997-07-31
# 460390    Mr. TRAFICANT. Mr. Speaker, Louis Freeh said... 1997-07-31
# 460391    Mr. GILMAN. Mr. Speaker, I ask that all Memb... 1997-07-31
# 460392    Mr. KENNEDY of Rhode Island. Mr. Speaker, to... 1997-07-31
# 460393    Mr. CONYERS. Mr. Speaker, Members of the Hou... 1997-07-31
# 460394    Mr. HOEKSTRA. Mr. Speaker, I ask unanimous c... 1997-07-31
# 460395    Mr. PALLONE. Mr. Speaker, how much will it c... 1997-07-31
# 460396    Mr. ENGEL. Mr. Speaker, reserving the right ... 1997-07-31
# 460397    Mr. FAZIO of California. Mr. Speaker, I offe... 1997-07-31
# 460398    Mr. GILMAN. Mr. Speaker, will the gentleman ... 1997-07-31
# 460399    Ms. JACKSON-LEE of Texas. Mr. Speaker, will ... 1997-07-31
# 460400    Mr. KUCINICH. Mr. Speaker, I rise to celebra... 1997-07-31
# 460401    Mr. ARMEY. Mr. Speaker, I move a call of the... 1997-07-31
# 460402    Mr. HAYWORTH. Mr. Speaker, to be certain, ca... 1997-07-31
# 460403    Mr. HOEKSTRA. Mr. Speaker, I ask unanimous c... 1997-07-31
# 460404    Mr. BOB SCHAFFER of Colorado. Mr. Speaker, I... 1997-07-31
# 460405    Mr. HOEKSTRA. Mr. Speaker, I ask unanimous c... 1997-07-31
# 460406    Mr. BOEHNER. Mr. Speaker, I offer a privileg... 1997-07-31
# 460407    Mr. FAZIO of California. Mr. Speaker, I than... 1997-07-31
# 460408    Mr. GOODLING. I thank the gentleman for yiel... 1997-07-31
# 460409    Mr. HOYER. Mr. Speaker, I yield such time as... 1997-07-31
# 460410    Mr. THOMAS. Mr. Speaker, I thank the gentlem... 1997-07-31
# 460411    Mrs. ROUKEMA. Mr. Speaker, I am pleased to h... 1997-07-31
# 460412    Mr. BLUMENAUER. Mr. Speaker, I submit for th... 1997-07-31
# 460413    Mr. CHABOT. Mr. Speaker, for the first time ... 1997-07-31
# 460414    Ms. KILPATRICK. Mr. Speaker, I rise in suppo... 1997-07-31
# 460415    Ms. ROS-LEHTINEN. Mr. Speaker, we rise to ho... 1997-07-31
#
#                                                 doc_title  \
# 0       MARRIAGE PENALTY AND FAMILY TAX RELIEF ACT OF ...
# 1       MARRIAGE PENALTY AND FAMILY TAX RELIEF ACT OF ...
# 2       RECOGNIZING EVAN DOBELLE'S CONTRIBUTIONS TO TH...
# 3                                      MAGGIE LENA WALKER
# 4       CONCURRENT RESOLUTION ON THE BUDGET, FISCAL YE...
# 5           CONGRATULATING CLOUD COUNTY COMMUNITY COLLEGE
# 6       IN RECOGNITION OF CAROLYN CRAYTON, THE FOUNDER...
# 7       STOP THE TIDE OF SUBSIDIZED CANADIAN LUMBER FR...
# 8                            ACHIEVEMENTS OF CESAR CHAVEZ
# 9                                   DR. ROGER D. WILLMORE
# 10                                            ADJOURNMENT
# 11          HONORING SOUTH SALT LAKE MAYOR RANDY G. FITTS
# 12         HONORING THE DEDICATED SERVICE OF LOUIS FINKEL
# 13      THE CONSUMER AND RETAIL SALES STIMULUS ACT OF ...
# 14                 COMMEMORATING 2001 DINNER OF CHAMPIONS
# 15      CONFERENCE REPORT ON H.R. 2299, DEPARTMENT OF ...
# 16      CONFERENCE REPORT ON H.R. 2299, DEPARTMENT OF ...
# 17      CONFERENCE REPORT ON H.R. 2299, DEPARTMENT OF ...
# 18      CONFERENCE REPORT ON H.R. 2299, DEPARTMENT OF ...
# 19      CONFERENCE REPORT ON H.R. 2299, DEPARTMENT OF ...
# 20      CONFERENCE REPORT ON H.R. 2299, DEPARTMENT OF ...
# 21      CONFERENCE REPORT ON H.R. 2299, DEPARTMENT OF ...
# 22      CONFERENCE REPORT ON H.R. 2299, DEPARTMENT OF ...
# 23      CONFERENCE REPORT ON H.R. 2299, DEPARTMENT OF ...
# 24      CONFERENCE REPORT ON H.R. 2299, DEPARTMENT OF ...
# 25      CONFERENCE REPORT ON H.R. 2299, DEPARTMENT OF ...
# 26      INTRODUCTION OF LEGISLATION CONVEYING PROPERTY...
# 27                                          GENERAL LEAVE
# 28                                IN MEMORY OF JANE MAYER
# 29                                    AMERICA'S RECESSION
# ...                                                   ...
# 460386  FAREWELL AND GOOD LUCK TO THE HONORABLE SUSAN ...
# 460387  FAREWELL AND GOOD LUCK TO THE HONORABLE SUSAN ...
# 460388  FAREWELL AND GOOD LUCK TO THE HONORABLE SUSAN ...
# 460389                       GREAT DAY FOR EVERY AMERICAN
# 460390                  FBI LEAKS TO PRESS ARE NO MISTAKE
# 460391                                      GENERAL LEAVE
# 460392                        INTRODUCTION OF LEGISLATION
# 460393                             GRAND JURY PROCEEDINGS
# 460394  AUTHORIZING THE SPEAKER, THE MAJORITY LEADER, ...
# 460395                              MOLLIFYING BOB DORNAN
# 460396  ELECTION OF MEMBERS TO CERTAIN STANDING COMMIT...
# 460397  ELECTION OF MEMBERS TO CERTAIN STANDING COMMIT...
# 460398  ELECTION OF MEMBERS TO CERTAIN STANDING COMMIT...
# 460399  ELECTION OF MEMBERS TO CERTAIN STANDING COMMIT...
# 460400  IN HONOR OF THE NEW FAIRVIEW PARK REGIONAL LIB...
# 460401                                  CALL OF THE HOUSE
# 460402         FAMILY FINANCE QUESTIONS SHOULD COME FIRST
# 460403                                      GENERAL LEAVE
# 460404            TRIBUTE TO FOREIGN LANGUAGES IN SCHOOLS
# 460405  DISPENSING WITH CALENDAR WEDNESDAY BUSINESS ON...
# 460406           ELECTION OF CHIEF ADMINISTRATIVE OFFICER
# 460407           ELECTION OF CHIEF ADMINISTRATIVE OFFICER
# 460408           ELECTION OF CHIEF ADMINISTRATIVE OFFICER
# 460409           ELECTION OF CHIEF ADMINISTRATIVE OFFICER
# 460410           ELECTION OF CHIEF ADMINISTRATIVE OFFICER
# 460411         100TH ANNIVERSARY OF KPMG PEAT MARWICK LLP
# 460412                                 GIVE FANS A CHANCE
# 460413  105TH CONGRESS MAKES HISTORY WITH TAX CUTS FOR...
# 460414  TIME TO BRING THE INVESTIGATION OF CALIFORNIA'...
# 460415                     IN HONOR OF ZORA NEALE HURSTON
#
#                                    id                       speaker  \
# 0          CREC-2001-03-30-pt1-PgE503                  Mr. LANGEVIN
# 1        CREC-2001-03-30-pt1-PgE503-2                  Mr. BOEHLERT
# 2          CREC-2001-03-30-pt1-PgE504     Mr. LARSON of Connecticut
# 3          CREC-2001-03-30-pt1-PgE505                     Mr. SCOTT
# 4        CREC-2001-03-30-pt1-PgE504-2                  Mr. LANGEVIN
# 5        CREC-2001-03-30-pt1-PgE503-4           Mr. MORAN of Kansas
# 6        CREC-2001-03-30-pt1-PgE503-3                 Mr. CHAMBLISS
# 7         CREC-2001-03-30-pt1-PgH1350                   Mr. DeFAZIO
# 8        CREC-2001-03-30-pt1-PgE505-2       Mr. HASTINGS of Florida
# 9       CREC-2001-03-30-pt1-PgH1349-6                     Mr. RILEY
# 10      CREC-2001-03-30-pt1-PgH1350-3                   Mr. DeFAZIO
# 11      CREC-2001-11-30-pt1-PgE2183-5                  Mr. MATHESON
# 12        CREC-2001-11-30-pt1-PgE2183                    Mr. GORDON
# 13      CREC-2001-11-30-pt1-PgE2185-3                    Mr. ISRAEL
# 14      CREC-2001-11-30-pt1-PgE2184-3                Mr. RADANOVICH
# 15      CREC-2001-11-30-pt1-PgH8734-2                    Mr. BORSKI
# 16      CREC-2001-11-30-pt1-PgH8734-2                     Mr. KOLBE
# 17      CREC-2001-11-30-pt1-PgH8734-2                 Mr. McDERMOTT
# 18      CREC-2001-11-30-pt1-PgH8734-2                  Mr. OBERSTAR
# 19      CREC-2001-11-30-pt1-PgH8734-2                     Mr. OLVER
# 20      CREC-2001-11-30-pt1-PgH8734-2                    Mr. PASTOR
# 21      CREC-2001-11-30-pt1-PgH8734-2        Mr. ROGERS of Kentucky
# 22      CREC-2001-11-30-pt1-PgH8734-2                      Mr. SABO
# 23      CREC-2001-11-30-pt1-PgH8734-2                      Mr. WOLF
# 24      CREC-2001-11-30-pt1-PgH8734-2          Mr. YOUNG of Florida
# 25      CREC-2001-11-30-pt1-PgH8734-2                Ms. KILPATRICK
# 26      CREC-2001-11-30-pt1-PgH8741-5                  Mrs. MORELLA
# 27        CREC-2001-11-30-pt1-PgH8734        Mr. ROGERS of Kentucky
# 28      CREC-2001-11-30-pt1-PgE2186-3        Mr. FARR of California
# 29      CREC-2001-11-30-pt1-PgH8742-5                     Mr. PENCE
# ...                               ...                           ...
# 460386    CREC-1997-07-31-pt1-PgH6665                     Mr. PAXON
# 460387    CREC-1997-07-31-pt1-PgH6665                     Mr. QUINN
# 460388    CREC-1997-07-31-pt1-PgH6665              Ms. ROS-LEHTINEN
# 460389  CREC-1997-07-31-pt1-PgH6622-6                    Mr. DREIER
# 460390  CREC-1997-07-31-pt1-PgH6620-7                 Mr. TRAFICANT
# 460391    CREC-1997-07-31-pt1-PgH6680                    Mr. GILMAN
# 460392  CREC-1997-07-31-pt1-PgE1567-2   Mr. KENNEDY of Rhode Island
# 460393    CREC-1997-07-31-pt1-PgH6688                   Mr. CONYERS
# 460394  CREC-1997-07-31-pt1-PgH6684-2                  Mr. HOEKSTRA
# 460395  CREC-1997-07-31-pt1-PgH6620-3                   Mr. PALLONE
# 460396  CREC-1997-07-31-pt1-PgH6678-3                     Mr. ENGEL
# 460397  CREC-1997-07-31-pt1-PgH6678-3       Mr. FAZIO of California
# 460398  CREC-1997-07-31-pt1-PgH6678-3                    Mr. GILMAN
# 460399  CREC-1997-07-31-pt1-PgH6678-3      Ms. JACKSON-LEE of Texas
# 460400  CREC-1997-07-31-pt1-PgE1566-3                  Mr. KUCINICH
# 460401    CREC-1997-07-31-pt1-PgH6662                     Mr. ARMEY
# 460402  CREC-1997-07-31-pt1-PgH6621-4                  Mr. HAYWORTH
# 460403    CREC-1997-07-31-pt1-PgH6684                  Mr. HOEKSTRA
# 460404  CREC-1997-07-31-pt1-PgE1573-3  Mr. BOB SCHAFFER of Colorado
# 460405  CREC-1997-07-31-pt1-PgH6684-4                  Mr. HOEKSTRA
# 460406  CREC-1997-07-31-pt1-PgH6669-2                   Mr. BOEHNER
# 460407  CREC-1997-07-31-pt1-PgH6669-2       Mr. FAZIO of California
# 460408  CREC-1997-07-31-pt1-PgH6669-2                  Mr. GOODLING
# 460409  CREC-1997-07-31-pt1-PgH6669-2                     Mr. HOYER
# 460410  CREC-1997-07-31-pt1-PgH6669-2                    Mr. THOMAS
# 460411    CREC-1997-07-31-pt1-PgE1569                  Mrs. ROUKEMA
# 460412    CREC-1997-07-31-pt1-PgE1570                Mr. BLUMENAUER
# 460413  CREC-1997-07-31-pt1-PgH6620-4                    Mr. CHABOT
# 460414  CREC-1997-07-31-pt1-PgH6621-5                Ms. KILPATRICK
# 460415  CREC-1997-07-31-pt1-PgE1568-3              Ms. ROS-LEHTINEN
#
#        speaker_bioguide first_name     last_name gender
# 0               L000559      James      Langevin      M
# 1               B000586   Sherwood      Boehlert      M
# 2               L000557       John        Larson      M
# 3               S000185     Robert         Scott      M
# 4               L000559      James      Langevin      M
# 5               M000934      Jerry         Moran      M
# 6               C000286      Saxby     Chambliss      M
# 7               D000191      Peter       DeFazio      M
# 8               H000324      Alcee      Hastings      M
# 9               R000258        Bob         Riley      M
# 10              D000191      Peter       DeFazio      M
# 11              M001142        Jim      Matheson      M
# 12              G000309     Barton        Gordon      M
# 13              I000057      Steve        Israel      M
# 14              R000004     George    Radanovich      M
# 15              B000644     Robert        Borski      M
# 16              K000306      James         Kolbe      M
# 17              M000404        Jim     McDermott      M
# 18              O000006      James      Oberstar      M
# 19              O000085       John         Olver      M
# 20              P000099         Ed        Pastor      M
# 21              R000395     Harold        Rogers      M
# 22              S000005     Martin          Sabo      M
# 23              W000672      Frank          Wolf      M
# 24              Y000031         C.         Young      M
# 25              K000180    Carolyn    Kilpatrick      F
# 26              M000941  Constance       Morella      F
# 27              R000395     Harold        Rogers      M
# 28              F000030        Sam          Farr      M
# 29              P000587       Mike         Pence      M
# ...                 ...        ...           ...    ...
# 460386          P000148         L.         Paxon      M
# 460387          Q000016       Jack         Quinn      M
# 460388          R000435     Ileana  Ros-Lehtinen      F
# 460389          D000492      David        Dreier      M
# 460390          T000350      James     Traficant      M
# 460391          G000212   Benjamin        Gilman      M
# 460392          K000113    Patrick       Kennedy      M
# 460393          C000714       John       Conyers      M
# 460394          H000676      Peter      Hoekstra      M
# 460395          P000034      Frank       Pallone      M
# 460396          E000179      Eliot         Engel      M
# 460397          F000053     Victor         Fazio      M
# 460398          G000212   Benjamin        Gilman      M
# 460399          J000032     Sheila   Jackson Lee      F
# 460400          K000336     Dennis      Kucinich      M
# 460401          A000217    Richard         Armey      M
# 460402          H000413       John      Hayworth      M
# 460403          H000676      Peter      Hoekstra      M
# 460404          S000112        Bob      Schaffer      M
# 460405          H000676      Peter      Hoekstra      M
# 460406          B000589       John       Boehner      M
# 460407          F000053     Victor         Fazio      M
# 460408          G000291    William      Goodling      M
# 460409          H000874      Steny         Hoyer      M
# 460410          T000188    William        Thomas      M
# 460411          R000465      Marge       Roukema      F
# 460412          B000574       Earl    Blumenauer      M
# 460413          C000266      Steve        Chabot      M
# 460414          K000180    Carolyn    Kilpatrick      F
# 460415          R000435     Ileana  Ros-Lehtinen      F
#
# [460416 rows x 9 columns]

# %% [markdown]
# Separate out speeches into body and metadata dataframes so that we can lazy load the speech bodies later.

# %%
import bcolz

# Save data to hdf5
speeches.drop("body", axis=1).to_hdf("speeches_metadata.h5", "metadata", mode="w", format="table")

# Save speeches to bcolz array
bcolz.carray(speeches["body"].str.replace("\n", " "), rootdir="speeches.bcolz", chunklen=10000000, cparams=bcolz.cparams(cname="lz4hc"))
# Out:
# ERROR:root:Line magic function `%file` not found (But cell magic `%%file` exists, did you mean that instead?).

# %%
# Save files that have been processed so that in the future we can append to speeches dataframe without duplicating work
pd.Series(files).to_csv("processed_files.csv", index=False)

# %%
del speeches
